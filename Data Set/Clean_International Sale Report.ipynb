# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.style as style
from datetime import datetime
isr=pd.read_csv("C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report.csv")
isr
# Out:
#        index      DATE    Months            CUSTOMER     Style  \
# 0          0  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 1          1  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 2          2  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5004
# 3          3  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5009
# 4          4  06-05-21    Jun-21  REVATHY LOGANATHAN   MEN5011
# ...      ...       ...       ...                 ...       ...
# 37427  37427    AVIN    03-31-22              Mar-22  PJNE3423
# 37428  37428    AVIN    03-31-22              Mar-22  PJNE3404
# 37429  37429    AVIN    03-31-22              Mar-22  PJNE3423
# 37430  37430    AVIN    03-31-22              Mar-22    SET290
# 37431  37431    AVIN    03-31-22              Mar-22  SHIPPING
#
#                    SKU  Size      PCS     RATE GROSS AMT
# 0         MEN5004-KR-L     L     1.00   616.56    617.00
# 1        MEN5004-KR-XL    XL     1.00   616.56    617.00
# ...

# %%
## este archivo se compone de 4 datafreme, se los cuales solo usaremos 2, el primero y el ultimo. 
## Primero elimino los datos nulos, y para eso averiguo cual es el porcentaje de nulos por cada columna

# %%
##Revisamos el tipo de dato para cada columna
isr.dtypes
# Out:
# index         int64
# DATE         object
# Months       object
# CUSTOMER     object
# Style        object
# SKU          object
# Size         object
# PCS          object
# RATE         object
# GROSS AMT    object
# dtype: object

# %%
##Contar los datos por cada columna
isr.count()
# Out:
# index        37432
# DATE         37431
# Months       37407
# CUSTOMER     36392
# Style        36392
# SKU          34958
# Size         36392
# PCS          36392
# RATE         36392
# GROSS AMT    36392
# dtype: int64

# %%
isr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37432 entries, 0 to 37431
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      37432 non-null  int64
#  1   DATE       37431 non-null  object
#  2   Months     37407 non-null  object
#  3   CUSTOMER   36392 non-null  object
#  4   Style      36392 non-null  object
#  5   SKU        34958 non-null  object
#  6   Size       36392 non-null  object
#  7   PCS        36392 non-null  object
#  8   RATE       36392 non-null  object
#  9   GROSS AMT  36392 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.9+ MB

# %%
##porcentaje de valores nulos por columna
round(isr.isnull().sum() / isr.shape[0] * 100.00,2)
# Out:
# index        0.00
# DATE         0.00
# Months       0.07
# CUSTOMER     2.78
# Style        2.78
# SKU          6.61
# Size         2.78
# PCS          2.78
# RATE         2.78
# GROSS AMT    2.78
# dtype: float64

# %%
# Adicional a lo anterior, reviso los datos de cada columna. Se puede ver que hay diferentes tipos de datos en las columnas.
for col in isr.columns:
    print("Column:",col, "\n\n", isr[col].value_counts(),"\n")
# Out:
# Column: index
#
#  0        1
# 24966    1
# 24950    1
# 24951    1
# 24952    1
#         ..
# 12478    1
# 12479    1
# 12480    1
# 12481    1
# 37431    1
# Name: index, Length: 37432, dtype: int64
#
# Column: DATE
#
#  MULBERRIES BOUTIQUE    1904
# 09-14-21                700
# COTTON CLOSET LTD       659
# 07-09-21                657
# 03-03-22                657
#                        ...
# JNE3553                   1
# JNE3546                   1
# JNE3622                   1
# JNE3516                   1
# JNE3507                   1
# Name: DATE, Length: 1326, dtype: int64
#
# Column: Months
#
#  Feb-22    3380
# Oct-21    3098
# Mar-22    2263
# Nov-21    1816
# Sep-21    1497
#           ...
# 233.00       1
# 874.00       1
# 189.00       1
# 568.00       1
# 151.00       1
# Name: Months, Length: 571, dtype: int64
#
# Column: CUSTOMER
#
#  Feb-22                    3448
# Oct-21                    3176
# Mar-22                    2327
# ...

# %%
## en la revisión de datos se puede ver que en la columna SKU, hay un dato con el mimo nombre. Busco la posición de ese dato.
SKU = isr[isr['SKU'] == 'SKU' ]
SKU.head()
# Out:
#        index      DATE Months CUSTOMER  Style  SKU Size   PCS       RATE  \
# 19675  19675  CUSTOMER   DATE   Months  Style  SKU  PCS  RATE  GROSS AMT
#
#       GROSS AMT
# 19675     Stock

# %%
##mostrar datos desde fila 19675
isr.loc[isr['index']>=int(SKU['index'])]
# Out:
#        index                DATE    Months CUSTOMER     Style  \
# 19675  19675            CUSTOMER      DATE   Months     Style
# 19676  19676  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 19677  19677  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 19678  19678  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 19679  19679  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5009
# ...      ...                 ...       ...      ...       ...
# 37427  37427              AVIN    03-31-22   Mar-22  PJNE3423
# 37428  37428              AVIN    03-31-22   Mar-22  PJNE3404
# 37429  37429              AVIN    03-31-22   Mar-22  PJNE3423
# 37430  37430              AVIN    03-31-22   Mar-22    SET290
# 37431  37431              AVIN    03-31-22   Mar-22  SHIPPING
#
#                    SKU  Size      PCS       RATE GROSS AMT
# 19675              SKU   PCS     RATE  GROSS AMT     Stock
# 19676     MEN5004-KR-L  1.00   616.56     617.00      8.00
# ...

# %%
# separar en 2 archivos.csv el df, según la posición encontrada.
k = 2
size = int(SKU['index'])

for i in range(k):
    df = isr[size*i:size*(i+1)]

    df.to_csv(f'International Sale Report{i+1}.csv', index=False)

file1 = pd.read_csv("International Sale Report1.csv")
print(file1)
print("\n")
file2 = pd.read_csv("International Sale Report2.csv")
print(file2)
# Out:
#        index      DATE  Months            CUSTOMER    Style             SKU  \
# 0          0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L
# 1          1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL
# 2          2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL
# 3          3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L
# 4          4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L
# ...      ...       ...     ...                 ...      ...             ...
# 19670  19670     J0419  313.00                 NaN      NaN             NaN
# 19671  19671   JNE3905  299.00                 NaN      NaN             NaN
# 19672  19672   JAN8623    0.00                 NaN      NaN             NaN
# 19673  19673     J0391  270.00                 NaN      NaN             NaN
# 19674  19674     J0390  240.00                 NaN      NaN             NaN
#
#       Size  PCS    RATE  GROSS AMT
# ...

# %%
##Grabar archivo 1
ruta_csv = "C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_1.csv"
file1.to_csv(ruta_csv, index=False)

# %%
##Grabar archivo 2
ruta_csv = "C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_2.csv"
file2.to_csv(ruta_csv, index=False)

# %% [markdown]
# # Limpieza archivo 1

# %%
##cargar Arhcivo 1

isr1=pd.read_csv("C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_1.csv")
isr1
# Out:
#        index      DATE  Months            CUSTOMER    Style             SKU  \
# 0          0  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004    MEN5004-KR-L
# 1          1  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004   MEN5004-KR-XL
# 2          2  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5004  MEN5004-KR-XXL
# 3          3  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5009    MEN5009-KR-L
# 4          4  06-05-21  Jun-21  REVATHY LOGANATHAN  MEN5011    MEN5011-KR-L
# ...      ...       ...     ...                 ...      ...             ...
# 19670  19670     J0419  313.00                 NaN      NaN             NaN
# 19671  19671   JNE3905  299.00                 NaN      NaN             NaN
# 19672  19672   JAN8623    0.00                 NaN      NaN             NaN
# 19673  19673     J0391  270.00                 NaN      NaN             NaN
# 19674  19674     J0390  240.00                 NaN      NaN             NaN
#
#       Size  PCS    RATE  GROSS AMT
# ...

# %%
## ver nombres de columnas
isr1.columns
# Out:
# Index(['index', 'DATE', 'Months', 'CUSTOMER', 'Style', 'SKU', 'Size', 'PCS',
#        'RATE', 'GROSS AMT'],
#       dtype='object')

# %%
##Visualizar datos donde hay valores Nulos
null_columns=isr1.columns[isr1.isnull().any()]
isr1[null_columns].isnull().sum()
print(isr1[isr1.isnull().any(axis=1)][null_columns].head())
# Out:
#           DATE  Months      CUSTOMER    Style  SKU  Size  PCS   RATE  \
# 2810  08-25-21  Aug-21  BINCY SKARIA  JNE1234  NaN  Free  1.0  409.0
# 2811  08-25-21  Aug-21  BINCY SKARIA  JNE1234  NaN  Free  1.0  409.0
# 2812  08-25-21  Aug-21  BINCY SKARIA  JNE1234  NaN  Free  1.0  409.0
# 2814  08-25-21  Aug-21  BINCY SKARIA  JNE1408  NaN  Free  1.0  469.0
# 2815  08-25-21  Aug-21  BINCY SKARIA  JNE1408  NaN  Free  1.0  469.0
#
#       GROSS AMT
# 2810      401.0
# 2811      401.0
# 2812      401.0
# 2814      460.0
# 2815      460.0

# %%
## Elimino los Nulos
isr1=isr1.dropna()

# %%
##reviso si se eliminaron todos los nulos
round(isr1.isnull().sum() / isr1.shape[0] * 100.00,2)
# Out:
# index        0.0
# DATE         0.0
# Months       0.0
# CUSTOMER     0.0
# Style        0.0
# SKU          0.0
# Size         0.0
# PCS          0.0
# RATE         0.0
# GROSS AMT    0.0
# dtype: float64

# %%
isr1
# Out:
#        index       DATE  Months            CUSTOMER     Style  \
# 0          0 2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 1          1 2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 2          2 2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 3          3 2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5009
# 4          4 2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5011
# ...      ...        ...     ...                 ...       ...
# 17230  17230 2022-03-31  Mar-22              AVIN      SET276
# 17231  17231 2022-03-31  Mar-22              AVIN    PJNE3423
# 17232  17232 2022-03-31  Mar-22              AVIN    PJNE3404
# 17233  17233 2022-03-31  Mar-22              AVIN    PJNE3423
# 17234  17234 2022-03-31  Mar-22              AVIN      SET290
#
#                    SKU Size  PCS     RATE  GROSS AMT
# 0         MEN5004-KR-L    L  1.0   616.56      617.0
# 1        MEN5004-KR-XL   XL  1.0   616.56      617.0
# 2       MEN5004-KR-XXL  XXL  1.0   616.56      617.0
# ...

# %%
## ULTIPO PASO. Dar formato Fecha a columna DATE
isr1['DATE'] = pd.to_datetime(isr1['DATE'])
print(isr1["DATE"])
# Out:
# 0       2021-06-05
# 1       2021-06-05
# 2       2021-06-05
# 3       2021-06-05
# 4       2021-06-05
#            ...
# 17230   2022-03-31
# 17231   2022-03-31
# 17232   2022-03-31
# 17233   2022-03-31
# 17234   2022-03-31
# Name: DATE, Length: 17218, dtype: datetime64[ns]
# C:\Users\felip\AppData\Local\Temp\ipykernel_25168\2696520964.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isr1['DATE'] = pd.to_datetime(isr1['DATE'])

# %%
isr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17218 entries, 0 to 17234
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      17218 non-null  int64
#  1   DATE       17218 non-null  datetime64[ns]
#  2   Months     17218 non-null  object
#  3   CUSTOMER   17218 non-null  object
#  4   Style      17218 non-null  object
#  5   SKU        17218 non-null  object
#  6   Size       17218 non-null  object
#  7   PCS        17218 non-null  float64
#  8   RATE       17218 non-null  float64
#  9   GROSS AMT  17218 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(5)
# memory usage: 1.4+ MB

# %%
## Cambiar tipo de dato flotante a numérico
isr1['PCS'] = isr1['PCS'].astype('int64')
isr1['RATE'] = isr1['RATE'].astype('int64')
isr1['GROSS AMT'] = isr1['GROSS AMT'].astype('int64')
isr1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17218 entries, 0 to 17234
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      17218 non-null  int64
#  1   DATE       17218 non-null  datetime64[ns]
#  2   Months     17218 non-null  object
#  3   CUSTOMER   17218 non-null  object
#  4   Style      17218 non-null  object
#  5   SKU        17218 non-null  object
#  6   Size       17218 non-null  object
#  7   PCS        17218 non-null  int64
#  8   RATE       17218 non-null  int64
#  9   GROSS AMT  17218 non-null  int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 1.4+ MB
# C:\Users\felip\AppData\Local\Temp\ipykernel_25168\2750046978.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
##Grabar archivo 1
ruta_csv = "C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_1_clean.csv"
isr1.to_csv(ruta_csv, index=False)

# %%
##Cargar archivo 1 para confirmar proceso completado
isr1_clean=pd.read_csv("C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_1_clean.csv")
isr1_clean
# Out:
#        index        DATE  Months            CUSTOMER     Style  \
# 0          0  2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 1          1  2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 2          2  2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5004
# 3          3  2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5009
# 4          4  2021-06-05  Jun-21  REVATHY LOGANATHAN   MEN5011
# ...      ...         ...     ...                 ...       ...
# 17213  17230  2022-03-31  Mar-22              AVIN      SET276
# 17214  17231  2022-03-31  Mar-22              AVIN    PJNE3423
# 17215  17232  2022-03-31  Mar-22              AVIN    PJNE3404
# 17216  17233  2022-03-31  Mar-22              AVIN    PJNE3423
# 17217  17234  2022-03-31  Mar-22              AVIN      SET290
#
#                    SKU Size  PCS     RATE  GROSS AMT
# 0         MEN5004-KR-L    L  1.0   616.56      617.0
# 1        MEN5004-KR-XL   XL  1.0   616.56      617.0
# ...

# %% [markdown]
# # Lipieza Archivo 2

# %%
##Cargar archivo 2
isr2=pd.read_csv("C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_2.csv")
isr2
# Out:
#        index                DATE    Months CUSTOMER     Style  \
# 0      19675            CUSTOMER      DATE   Months     Style
# 1      19676  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 2      19677  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 3      19678  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5004
# 4      19679  REVATHY LOGANATHAN  06-05-21   Jun-21   MEN5009
# ...      ...                 ...       ...      ...       ...
# 17752  37427              AVIN    03-31-22   Mar-22  PJNE3423
# 17753  37428              AVIN    03-31-22   Mar-22  PJNE3404
# 17754  37429              AVIN    03-31-22   Mar-22  PJNE3423
# 17755  37430              AVIN    03-31-22   Mar-22    SET290
# 17756  37431              AVIN    03-31-22   Mar-22  SHIPPING
#
#                    SKU  Size      PCS       RATE GROSS AMT
# 0                  SKU   PCS     RATE  GROSS AMT     Stock
# 1         MEN5004-KR-L  1.00   616.56     617.00      8.00
# ...

# %%
## este df indica el stock de cada SKU. Consotruiremos un nuevo archivo.csv con el stock.
## ver nombres de columnas para cambiarla
isr2.columns
# Out:
# Index(['index', 'DATE', 'Months', 'CUSTOMER', 'Style', 'SKU', 'Size', 'PCS',
#        'RATE', 'GROSS AMT'],
#       dtype='object')

# %%
##cambiar nombres
isr2.columns = ['index', 'CUSTOMER', 'DATE', 'Months', 'Style', 'SKU','PCS','RATE','GROSS AMT','Stock']
isr2
# Out:
#        index            CUSTOMER      DATE  Months     Style              SKU  \
# 0      19675            CUSTOMER      DATE  Months     Style              SKU
# 1      19676  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004     MEN5004-KR-L
# 2      19677  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004    MEN5004-KR-XL
# 3      19678  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004   MEN5004-KR-XXL
# 4      19679  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5009     MEN5009-KR-L
# ...      ...                 ...       ...     ...       ...              ...
# 17752  37427              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17753  37428              AVIN    03-31-22  Mar-22  PJNE3404  PJNE3404-KR-4XL
# 17754  37429              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17755  37430              AVIN    03-31-22  Mar-22    SET290  SET290-KR-DPT-M
# 17756  37431              AVIN    03-31-22  Mar-22  SHIPPING         SHIPPING
#
# ...

# %%
## elimina primer registro que tiene el nombre de la columna
isr2.drop([0], axis=0, inplace=True)
isr2
# Out:
#        index            CUSTOMER      DATE  Months     Style              SKU  \
# 1      19676  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004     MEN5004-KR-L
# 2      19677  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004    MEN5004-KR-XL
# 3      19678  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004   MEN5004-KR-XXL
# 4      19679  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5009     MEN5009-KR-L
# 5      19680  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5011     MEN5011-KR-L
# ...      ...                 ...       ...     ...       ...              ...
# 17752  37427              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17753  37428              AVIN    03-31-22  Mar-22  PJNE3404  PJNE3404-KR-4XL
# 17754  37429              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17755  37430              AVIN    03-31-22  Mar-22    SET290  SET290-KR-DPT-M
# 17756  37431              AVIN    03-31-22  Mar-22  SHIPPING         SHIPPING
#
# ...

# %%
##reviso si hay datos nulos en esta parte del dataset
round(isr2.isnull().sum() / isr2.shape[0] * 100.00,2)
# Out:
# index        0.0
# CUSTOMER     0.0
# DATE         0.0
# Months       0.0
# Style        0.0
# SKU          0.1
# PCS          0.0
# RATE         0.0
# GROSS AMT    0.0
# Stock        0.0
# dtype: float64

# %%
## Elimino los Nulos
isr2=isr2.dropna()
isr2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17739 entries, 1 to 17756
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      17739 non-null  int64
#  1   CUSTOMER   17739 non-null  object
#  2   DATE       17739 non-null  object
#  3   Months     17739 non-null  object
#  4   Style      17739 non-null  object
#  5   SKU        17739 non-null  object
#  6   PCS        17739 non-null  object
#  7   RATE       17739 non-null  object
#  8   GROSS AMT  17739 non-null  object
#  9   Stock      17739 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.5+ MB

# %%
# Función para extraer la talla de la columna SKU
def extraer_talla(SKU):
    partes = SKU.split('-')
    if len(partes) >= 2:
        return partes[-1]
    else:
        return None

# Aplicar la función a la columna SKU y crear una nueva columna 'talla'
isr2['Size'] = isr2['SKU'].apply(extraer_talla)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_25168\1918308268.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isr2['Size'] = isr2['SKU'].apply(extraer_talla)

# %%
isr2
# Out:
#        index            CUSTOMER      DATE  Months     Style              SKU  \
# 1      19676  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004     MEN5004-KR-L
# 2      19677  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004    MEN5004-KR-XL
# 3      19678  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5004   MEN5004-KR-XXL
# 4      19679  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5009     MEN5009-KR-L
# 5      19680  REVATHY LOGANATHAN  06-05-21  Jun-21   MEN5011     MEN5011-KR-L
# ...      ...                 ...       ...     ...       ...              ...
# 17752  37427              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17753  37428              AVIN    03-31-22  Mar-22  PJNE3404  PJNE3404-KR-4XL
# 17754  37429              AVIN    03-31-22  Mar-22  PJNE3423  PJNE3423-KR-4XL
# 17755  37430              AVIN    03-31-22  Mar-22    SET290  SET290-KR-DPT-M
# 17756  37431              AVIN    03-31-22  Mar-22  SHIPPING         SHIPPING
#
# ...

# %%
# revisar los datos de cada columna
for col in isr2.columns:
    print("Column:",col, "\n\n", isr2[col].value_counts(),"\n")
# Out:
# Column: index
#
#  19676    1
# 31511    1
# 31517    1
# 31516    1
# 31515    1
#         ..
# 25600    1
# 25601    1
# 25602    1
# 25603    1
# 37431    1
# Name: index, Length: 17739, dtype: int64
#
# Column: CUSTOMER
#
#  MULBERRIES BOUTIQUE          1904
# COTTON CLOSET LTD             659
# VAHARSHA BOUTIQUE             632
# ETHNIC WEAVES FASHION LLC     556
# RIVAAN LLC                    528
#                              ...
# VAHLAARMATHY                   11
# TASSELS LTD                    11
# MONIYSHAA                      10
# KASTHURI RAMASAMY               7
# AANCHOL                         5
# Name: CUSTOMER, Length: 125, dtype: int64
#
# Column: DATE
#
#  09-14-21    729
# 03-03-22    669
# 07-09-21    659
# 02-22-22    654
# 02-21-22    568
#            ...
# 09-09-21     11
# 09-29-21     11
# 07-12-21     11
# 07-13-21     10
# 10-13-21      4
# Name: DATE, Length: 138, dtype: int64
#
# Column: Months
#
#  Feb-22    3440
# Oct-21    3176
# Mar-22    2326
# ...

# %%
## En este dataset se puede concluir que son datos de stock. por lo tanto se deben eliminar columnas y luego eliminar los duplicados.
## Eliminar columnas 'index','CUSTOMER','DATE','Months','PCS','RATE','GROSS AMT'
isr2 = isr2.drop(columns=['index','CUSTOMER','DATE','Months','PCS','RATE','GROSS AMT'])
isr2
# Out:
#           Style              SKU  Stock  Size
# 1       MEN5004     MEN5004-KR-L   8.00     L
# 2       MEN5004    MEN5004-KR-XL   4.00    XL
# 3       MEN5004   MEN5004-KR-XXL   6.00   XXL
# 4       MEN5009     MEN5009-KR-L   6.00     L
# 5       MEN5011     MEN5011-KR-L  11.00     L
# ...         ...              ...    ...   ...
# 17752  PJNE3423  PJNE3423-KR-4XL   4.00   4XL
# 17753  PJNE3404  PJNE3404-KR-4XL   5.00   4XL
# 17754  PJNE3423  PJNE3423-KR-4XL   4.00   4XL
# 17755    SET290  SET290-KR-DPT-M   7.00     M
# 17756  SHIPPING         SHIPPING   0.00  None
#
# [17739 rows x 4 columns]

# %%
##Reordenar columnas archivo 2
isr2 = isr2.reindex(['SKU','Style','Size','Stock'], axis=1) 
isr2
# Out:
#                    SKU     Style  Size  Stock
# 1         MEN5004-KR-L   MEN5004     L   8.00
# 2        MEN5004-KR-XL   MEN5004    XL   4.00
# 3       MEN5004-KR-XXL   MEN5004   XXL   6.00
# 4         MEN5009-KR-L   MEN5009     L   6.00
# 5         MEN5011-KR-L   MEN5011     L  11.00
# ...                ...       ...   ...    ...
# 17752  PJNE3423-KR-4XL  PJNE3423   4XL   4.00
# 17753  PJNE3404-KR-4XL  PJNE3404   4XL   5.00
# 17754  PJNE3423-KR-4XL  PJNE3423   4XL   4.00
# 17755  SET290-KR-DPT-M    SET290     M   7.00
# 17756         SHIPPING  SHIPPING  None   0.00
#
# [17739 rows x 4 columns]

# %%
isr2.duplicated()
# Out:
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 17752     True
# 17753    False
# 17754     True
# 17755     True
# 17756     True
# Length: 17739, dtype: bool

# %%
isr2=isr2.drop_duplicates()
isr2
# Out:
#                    SKU     Style  Size  Stock
# 1         MEN5004-KR-L   MEN5004     L   8.00
# 2        MEN5004-KR-XL   MEN5004    XL   4.00
# 3       MEN5004-KR-XXL   MEN5004   XXL   6.00
# 4         MEN5009-KR-L   MEN5009     L   6.00
# 5         MEN5011-KR-L   MEN5011     L  11.00
# ...                ...       ...   ...    ...
# 17738   SET087-KR-PP-L    SET087     L   5.00
# 17741  SET330-KR-PP-XL    SET330    XL  35.00
# 17744  JNE3786-KR-XXXL   JNE3786  XXXL  43.00
# 17746   SET356-KR-NP-M    SET356     M  13.00
# 17753  PJNE3404-KR-4XL  PJNE3404   4XL   5.00
#
# [4599 rows x 4 columns]

# %%
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4599 entries, 0 to 4598
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SKU     4599 non-null   object
#  1   Style   4599 non-null   object
#  2   Size    4572 non-null   object
#  3   Stock   4599 non-null   float64
# dtypes: float64(1), object(3)
# memory usage: 143.8+ KB

# %%
stock['Stock'] = stock['Stock'].astype('int64')
stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4599 entries, 0 to 4598
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SKU     4599 non-null   object
#  1   Style   4599 non-null   object
#  2   Size    4572 non-null   object
#  3   Stock   4599 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 143.8+ KB

# %%
##Grabar archivo 2_Stock
ruta_csv = "C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_2_Stock.csv"
isr2.to_csv(ruta_csv, index=False)

# %%
## Cargar archivo de stock para confirmar proceso completo
stock=pd.read_csv("C:/Users/felip/Desktop/Master_BI_DM/Data Set/02 International sale Report_2_Stock.csv")
stock
# Out:
#                   SKU     Style  Size  Stock
# 0        MEN5004-KR-L   MEN5004     L    8.0
# 1       MEN5004-KR-XL   MEN5004    XL    4.0
# 2      MEN5004-KR-XXL   MEN5004   XXL    6.0
# 3        MEN5009-KR-L   MEN5009     L    6.0
# 4        MEN5011-KR-L   MEN5011     L   11.0
# ...               ...       ...   ...    ...
# 4594   SET087-KR-PP-L    SET087     L    5.0
# 4595  SET330-KR-PP-XL    SET330    XL   35.0
# 4596  JNE3786-KR-XXXL   JNE3786  XXXL   43.0
# 4597   SET356-KR-NP-M    SET356     M   13.0
# 4598  PJNE3404-KR-4XL  PJNE3404   4XL    5.0
#
# [4599 rows x 4 columns]

# %% [markdown]
# # Estadísticas Descriptivas

# %%
isr1.hist()
# Out:
# array([[<Axes: title={'center': 'index'}>,
#         <Axes: title={'center': 'DATE'}>],
#        [<Axes: title={'center': 'PCS'}>,
#         <Axes: title={'center': 'RATE'}>],
#        [<Axes: title={'center': 'GROSS AMT'}>, <Axes: >]], dtype=object)

# %%
stock.hist()
# Out:
# array([[<Axes: title={'center': 'Stock'}>]], dtype=object)

# %%
#Histograma
from seaborn import distplot
distplot(isr1_clean.PCS, hist=False)
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_25168\3369642833.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   distplot(isr1_clean.PCS, hist=False)
# <Axes: xlabel='PCS', ylabel='Density'>

# %%
from seaborn import lmplot
lmplot(x='PCS', y='RATE', data=isr1, fit_reg=True)
